# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn  as sns

# %%
iris = pd.read_csv("Iris.csv")
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
sns.pairplot(iris) # hue='variety'

# %%
titanic = pd.read_excel('titanic3.xls')

# Visualisation des categories
sns.catplot(x='pclass', y='age', data=titanic, hue='sex')

# %%
sns.boxplot(x='pclass', y='age', data=titanic, hue='sex')
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='age'>

# %%
# Visualisation des distriburion
sns.distplot(titanic['fare'])
# Out:
# C:\Users\Armand Forent\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='fare', ylabel='Density'>

# %%
sns.jointplot('age', 'fare', data=titanic, kind='kde') # kde=kernel density estimation

# %%
# Fonction heatmap utile pour afficher des matrices de correlation
sns.heatmap(titanic.corr())
# Out:
# <AxesSubplot:>

# %%
# Seaborn Vs Matplotlib
'''
- Seaborn: Dataset, Exploration statistique, vision globale
- Matplotlib: Fonctions, matrices, etc; mathematique, science, ingenierie, etc; graphique specialise
'''
